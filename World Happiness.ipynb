# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
#importing the dataset
df=pd.read_csv("Happiness Score.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
print("Total rows in the dataset:",df.shape[0])
print("Total columns in the dataset:",df.shape[1])
# Out:
# Total rows in the dataset: 158
# Total columns in the dataset: 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Here we can see there are no null values in the dataset.

# %% [markdown]
# # Visualization

# %% [markdown]
# # Uni-variate Analysis

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.distplot(df['Standard Error'],color='m')
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'],color='blue')
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'],color='darkred')
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.violinplot(df['Health (Life Expectancy)'],color='yellow')
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %%
sns.histplot(df['Freedom'],color='green')
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Count'>

# %%
sns.distplot(df['Trust (Government Corruption)'],color='purple')
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.histplot(df['Generosity'],color='black')
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Count'>

# %%
sns.distplot(df['Dystopia Residual'],color='pink')
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# # Bi-Variate Analysis

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.stripplot(x='Standard Error',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.lmplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df,palette='Dark2')

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.lmplot(x='Family',y='Dystopia Residual',hue='Country',data=df,palette='hls')

# %%
sns.lmplot(x='Health (Life Expectancy)',y='Dystopia Residual',data=df)

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)

# %%
sns.lmplot(x='Generosity',y='Happiness Score',data=df)

# %%
sns.lmplot(x='Happiness Score',y='Dystopia Residual',data=df)

# %% [markdown]
# # Multi-Variate Analysis

# %%
sns.pairplot(df,palette='hsl')

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
le=LabelEncoder()
list=['Country','Region']
for i in list:
    df[i]=le.fit_transform(df[i])
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Checking Outliers

# %%
plt.figure (figsize=(20,25))
p=1
for i in df:
    if p<=12:
        plt.subplot(5,3,p)
        sns.boxplot(df[i],palette='icefire_r')
        plt.xlabel(i)
    p+=1
plt.show()

# %%
#Removing Outliers
outliers=df[['Standard Error','Family','Trust (Government Corruption)','Generosity','Dystopia Residual']]

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(outliers))
z
# Out:
#      Standard Error    Family  Trust (Government Corruption)  Generosity  \
# 0          0.805926  1.320281                       2.309652    0.471040
# 1          0.055889  1.514458                       0.016480    1.575856
# 2          0.854487  1.361054                       2.842774    0.824293
# 3          0.531526  1.251922                       1.852081    0.868638
# 4          0.722845  1.221204                       1.555725    1.748563
# ..              ...       ...                            ...         ...
# 153        0.774917  0.800520                       3.413922    0.087228
# 154        0.662582  2.346860                       0.529210    0.433117
# 155        0.132534  1.901086                       0.381419    1.856891
# 156        2.263962  2.118467                       0.357715    0.316950
# 157        1.134182  3.134725                       0.301803    0.558153
#
#      Dystopia Residual
# 0             0.758258
# 1             1.092857
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([2, 0, 0, 0, 3, 1, 2, 4, 1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#Checking Data Loss after removing outliers
print("Old Data Shape =",df.shape)
print("New Data Shape =",df_new.shape)
print("Data Loss Percentage =",(df.shape[0]-df_new.shape[0])/df.shape[0]*100)
# Out:
# Old Data Shape = (158, 12)
# New Data Shape = (149, 12)
# Data Loss Percentage = 5.69620253164557

# %% [markdown]
# As we can see data loss percentage is 5.69%, we can proceed with the new data set.

# %%
df=df_new
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# # Checking Skewness

# %%
plt.figure (figsize=(20,25),facecolor='white')
p=1
for i in df:
    if p<=12:
        plt.subplot(5,3,p)
        sns.distplot(df[i],color='darkblue')
        plt.xlabel(i,fontsize=20)
    p+=1
plt.show()

# %%
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#Removing skewness
df['Standard Error']=np.cbrt(df['Standard Error'])
df['Trust (Government Corruption)']=np.cbrt(df['Trust (Government Corruption)'])

# %%
df.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# Now we can see the skewness has been removed.

# %%
#separating features and target variable
x=df.drop(['Happiness Score'],axis=1)
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0        135       9               1        0.324310
# 1         58       9               2        0.365532
# 2         37       9               3        0.321658
# 3        105       9               4        0.338540
# 4         24       5               5        0.328749
# ..       ...     ...             ...             ...
# 150       66       8             151        0.371834
# 151       20       8             152        0.350990
# 152        0       7             153        0.313597
# 154       13       8             155        0.331896
# 156       21       8             157        0.442391
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
y=df['Happiness Score']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
#Random_State
max_accu=0
max_RS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    dtr=DecisionTreeRegressor()
    dtr.fit(x_train,y_train)
    pred=dtr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>max_accu:
        max_accu=acc
        max_RS=i
print("Maximum R2 Score is",max_accu,"on random state",max_RS)
# Out:
# Maximum R2 Score is 0.998181686015538 on random state 156

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=max_RS)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_train.shape)
# Out:
# (119, 11)
# (119,)
# (30, 11)
# (119,)

# %%
#importing the necessary libraries for fitting the model
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print("R2 Score =",round(r2_score(y_test,predlr),2))
print("Mean Squared Error",mean_squared_error(y_test,predlr))
print("Mean Absolute Error",mean_absolute_error(y_test,predlr))
# Out:
# R2 Score = 1.0
# Mean Squared Error 0.0009081918031010703
# Mean Absolute Error 0.022736559928889937

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
print("R2 Score =",r2_score(y_test,pred_dtr))
print("Mean Squared Error",mean_squared_error(y_test,pred_dtr))
print("Mean Absolute Error",mean_absolute_error(y_test,pred_dtr))
# Out:
# R2 Score = 0.9952988803244461
# Mean Squared Error 0.005794633333333337
# Mean Absolute Error 0.059766666666666614

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr_pred=rfr.predict(x_test)
print("R2 score =",r2_score(y_test,rfr_pred))
print("Mean Squared Error =",mean_squared_error(y_test,rfr_pred))
print("Mean Absolute Error =",mean_absolute_error(y_test,rfr_pred))
# Out:
# R2 score = 0.9987817875672302
# Mean Squared Error = 0.0015015772533332643
# Mean Absolute Error = 0.029769999999999023

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
knr_pred=knr.predict(x_test)
print("R2 Score =",r2_score(y_test,knr_pred))
# Out:
# R2 Score = 0.9780248963903393

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CV is",(r2_score(y_test,predlr))-score.mean())
# Out:
# [0.92775634 0.97270787 0.94135042 0.95345774 0.99129941]
# 0.9573143544421768
# Difference between R2 score and CV is 0.04194883994664245

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("The Difference between R2 score and CV is",(r2_score(y_test,pred_dtr))-score.mean())
# Out:
# [-3.6320079  -0.44159323 -0.24536186 -0.60400515 -2.08271262]
# -1.4011361510484344
# The Difference between R2 score and CV is 2.3964350313728806

# %%
score=cross_val_score(rfr,x,y)
print(score)
print(score.mean())
print("The difference between R2 score and CV is",(r2_score(y_test,rfr_pred)-score.mean()))
# Out:
# [-4.25140451 -0.76263852 -0.28730855 -0.86849626 -2.65267549]
# -1.764504664329467
# The difference between R2 score and CV is 2.7632864518966973

# %% [markdown]
# Here we can see LinearRegression Model is having the least difference.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
lr=LinearRegression()
parameters={'n_jobs':[1,5,9,10,12,15]}
grid=GridSearchCV(estimator=lr,param_grid=parameters)
grid.fit(x,y)
print("SCORE =",grid.best_score_)
print(grid.best_params_)
# Out:
# SCORE = 0.9573143544421768
# {'n_jobs': 1}

# %%
final_model=lr
final_model
# Out:
# LinearRegression()

# %% [markdown]
# # Saving the best model

# %%
import joblib

# %%
joblib.dump(final_model,"World Happiness.pkl")
# Out:
# ['World Happiness.pkl']

# %% [markdown]
# # Predicting the saved model

# %%
model=joblib.load("World Happiness.pkl")
model.fit(x_train,y_train)
prediction=model.predict(x_test)
prediction
# Out:
# array([7.32270014, 5.12742427, 4.95241998, 3.59212134, 4.90553277,
#        4.49703556, 4.5877888 , 4.48644591, 4.50218004, 7.50823975,
#        6.48703617, 6.58604017, 7.25573743, 5.29222195, 4.85300047,
#        5.77682129, 5.73209907, 5.02443915, 5.88523132, 5.23408704,
#        7.22266907, 4.82997133, 4.23015063, 4.2714491 , 5.26809283,
#        7.37194476, 6.81255063, 6.48330368, 6.49234531, 4.51367227])

# %%
actual=np.array(y_test)
ds=pd.DataFrame()
ds['Predicted Value']=prediction
ds['Actual Value']=actual
ds
# Out:
#     Predicted Value  Actual Value
# 0          7.322700         7.406
# 1          5.127424         5.140
# 2          4.952420         4.971
# 3          3.592121         3.587
# 4          4.905533         4.885
# 5          4.497036         4.517
# 6          4.587789         4.565
# 7          4.486446         4.507
# 8          4.502180         4.512
# 9          7.508240         7.587
# 10         6.487036         6.505
# 11         6.586040         6.574
# 12         7.255737         7.284
# 13         5.292222         5.286
# 14         4.853000         4.839
# 15         5.776821         5.833
# 16         5.732099         5.759
# 17         5.024439         5.013
# 18         5.885231         5.855
# 19         5.234087         5.194
# 20         7.222669         7.200
# 21         4.829971         4.867
# 22         4.230151         4.252
# 23         4.271449         4.292
# 24         5.268093         5.268
# 25         7.371945         7.378
# ...
